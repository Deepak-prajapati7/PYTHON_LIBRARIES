# %%
import pandas as pd

# %%
df = pd.read_csv('/content/employees_pandas_practice.csv')
first_5rows = df.head(5)
print(first_5rows)
# Out:
#    Employee_ID           Name  Age  Gender  Department             Job_Role  \
# 0            1  Aditya Sharma   38    Male   Marketing  Marketing Executive
# 1            2    Tanya Patel   55  Female   Marketing    Marketing Manager
# 2            3    Akash Joshi   27  Female  Operations   Operations Manager
# 3            4    Varun Patel   25    Male   Marketing    Marketing Manager
# 4            5   Ishaan Gupta   31    Male     Finance      Finance Manager
#
#    Salary  Experience_Years        City Joining_Date  Performance_Score  \
# 0  114000                16  Chandigarh   2022-08-19                8.0
# 1  128000                25      Mumbai   2023-11-03                8.0
# 2   70000                 4       Noida   2017-05-30                8.0
# 3   59000                 3  Chandigarh   2020-04-09                8.0
# 4  106000                14         NaN   2018-06-22                8.0
#
#      Bonus Education
# 0      NaN    B.Tech
# 1  12800.0    M.Tech
# ...

# %%
last_rows = df.tail(10)
print(last_rows)
# Out:
#     Employee_ID           Name  Age  Gender        Department  \
# 90           91   Rahul Khanna   54    Male        Operations
# 91           92   Anika Mishra   45  Female             Sales
# 92           93     Yash Gupta   40  Female        Operations
# 93           94     Esha Mehta   29    Male                HR
# 94           95   Chetan Yadav   32    Male  Customer Support
# 95           96    Karan Ahuja   33  Female  Customer Support
# 96           97   Ananya Ahuja   44    Male                HR
# 97           98  Manish Sharma   47    Male      Data Science
# 98           99   Chetan Kumar   23  Female  Customer Support
# 99          100    Pooja Singh   39    Male             Sales
#
#                  Job_Role  Salary  Experience_Years        City Joining_Date  \
# 90     Operations Manager  141000                25      Jaipur   2024-09-11
# 91        Sales Executive  129000                25    Gurugram   2023-06-15
# ...

# %%
columns = df.columns
print(columns)
# Out:
# Index(['Employee_ID', 'Name', 'Age', 'Gender', 'Department', 'Job_Role',
#        'Salary', 'Experience_Years', 'City', 'Joining_Date',
#        'Performance_Score', 'Bonus', 'Education'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Employee_ID            int64
# Name                  object
# Age                    int64
# Gender                object
# Department            object
# Job_Role              object
# Salary                 int64
# Experience_Years       int64
# City                  object
# Joining_Date          object
# Performance_Score    float64
# Bonus                float64
# Education             object
# dtype: object

# %%
df.describe()
# Out:
#        Employee_ID         Age         Salary  Experience_Years  \
# count   100.000000  100.000000     100.000000        100.000000
# mean     50.500000   38.940000  111870.000000         17.230000
# std      29.011492   11.204995   30552.043692          7.692125
# min       1.000000   21.000000   43000.000000          0.000000
# 25%      25.750000   30.000000   88000.000000         12.000000
# 50%      50.500000   38.000000  116500.000000         18.000000
# 75%      75.250000   48.000000  133000.000000         25.000000
# max     100.000000   58.000000  170000.000000         25.000000
#
#        Performance_Score         Bonus
# count          96.000000     93.000000
# mean            7.791667   9793.010753
# std             1.337056   4227.120200
# min             5.000000   2400.000000
# 25%             7.000000   6600.000000
# 50%             8.000000   9720.000000
# 75%             9.000000  12300.000000
# max            10.000000  22200.000000

# %%
elements = df.size
print("total number of elements:",elements)
# Out:
# total number of elements: 1300

# %%
null_values = df.isnull().values.any()
print(null_values)
# Out:
# True

# %%
columns = df[['Name','Department','Salary']]
print(columns)
# Out:
#              Name        Department  Salary
# 0   Aditya Sharma         Marketing  114000
# 1     Tanya Patel         Marketing  128000
# 2     Akash Joshi        Operations   70000
# 3     Varun Patel         Marketing   59000
# 4    Ishaan Gupta           Finance  106000
# ..            ...               ...     ...
# 95    Karan Ahuja  Customer Support   88000
# 96   Ananya Ahuja                HR  115000
# 97  Manish Sharma      Data Science  166000
# 98   Chetan Kumar  Customer Support   66000
# 99    Pooja Singh             Sales  102000
#
# [100 rows x 3 columns]

# %%
print(df[df['Employee_ID'] == 105])
# Out:
# Empty DataFrame
# Columns: [Employee_ID, Name, Age, Gender, Department, Job_Role, Salary, Experience_Years, City, Joining_Date, Performance_Score, Bonus, Education]
# Index: []

# %%
print(df.iloc[0:10])
# Out:
#    Employee_ID             Name  Age  Gender  Department             Job_Role  \
# 0            1    Aditya Sharma   38    Male   Marketing  Marketing Executive
# 1            2      Tanya Patel   55  Female   Marketing    Marketing Manager
# 2            3      Akash Joshi   27  Female  Operations   Operations Manager
# 3            4      Varun Patel   25    Male   Marketing    Marketing Manager
# 4            5     Ishaan Gupta   31    Male     Finance      Finance Manager
# 5            6      Arjun Patel   57  Female   Marketing    Marketing Manager
# 6            7      Vikas Joshi   44    Male     Finance      Finance Manager
# 7            8  Shreya Malhotra   56    Male          HR           HR Manager
# 8            9      Diya Khanna   27  Female   Marketing  Marketing Executive
# 9           10      Karan Mehta   24    Male          HR         HR Executive
#
#    Salary  Experience_Years        City Joining_Date  Performance_Score  \
# ...

# %%
print(df[20:31])
# Out:
#     Employee_ID            Name  Age  Gender        Department  \
# 20           21     Isha Khanna   52  Female                IT
# 21           22    Pooja Mishra   21    Male                HR
# 22           23    Manish Patel   36    Male        Operations
# 23           24  Harsh Malhotra   31    Male      Data Science
# 24           25      Esha Joshi   42  Female                HR
# 25           26  Vikas Malhotra   23    Male      Data Science
# 26           27    Aarav Khanna   55    Male        Operations
# 27           28     Tanya Kumar   33  Female      Data Science
# 28           29      Riya Arora   49    Male  Customer Support
# 29           30    Gaurav Patel   30    Male                IT
# 30           31   Chetan Sharma   27  Female         Marketing
#
#                  Job_Role  Salary  Experience_Years        City Joining_Date  \
# 20      Software Engineer  149000                25       Delhi   2016-01-19
# ...

# %%
highest_salary = df['Salary'].max()
print("highest_salary is :", highest_salary)
# Out:
# highest_salary is : 170000

# %%
lowest_salary = df['Salary'].min()
print("lowest_salary is :", lowest_salary)
# Out:
# lowest_salary is : 43000

# %%
salary_greater = df[df['Salary'] > 50000]
print(salary_greater)

# %%
experience = df[df['Experience_Years'] > 5]
print("people have expericence more than five are :" ,experience)
# Out:
# people have expericence more than five are :     Employee_ID           Name  Age  Gender        Department  \
# 0             1  Aditya Sharma   38    Male         Marketing
# 1             2    Tanya Patel   55  Female         Marketing
# 4             5   Ishaan Gupta   31    Male           Finance
# 5             6    Arjun Patel   57  Female         Marketing
# 6             7    Vikas Joshi   44    Male           Finance
# ..          ...            ...  ...     ...               ...
# 95           96    Karan Ahuja   33  Female  Customer Support
# 96           97   Ananya Ahuja   44    Male                HR
# 97           98  Manish Sharma   47    Male      Data Science
# 98           99   Chetan Kumar   23  Female  Customer Support
# 99          100    Pooja Singh   39    Male             Sales
#
#                  Job_Role  Salary  Experience_Years        City Joining_Date  \
# 0     Marketing Executive  114000                16  Chandigarh   2022-08-19
# ...

# %%
id_department = df[df['Department'] == 'IT']
print(id_department)
# Out:
#     Employee_ID          Name  Age  Gender Department  \
# 11           12   Vikas Mehta   21    Male         IT
# 20           21   Isha Khanna   52  Female         IT
# 29           30  Gaurav Patel   30    Male         IT
# 51           52    Varun Rana   22  Female         IT
# 64           65   Aditi Joshi   38    Male         IT
# 65           66   Anika Verma   40  Female         IT
# 67           68  Tanya Chopra   26  Female         IT
# 88           89   Karan Arora   49    Male         IT
#
#                     Job_Role  Salary  Experience_Years        City  \
# 11         Software Engineer   54000                 0        Pune
# 20         Software Engineer  149000                25       Delhi
# 29         Software Engineer  122000                14  Chandigarh
# 51         Software Engineer   91000                 6     Kolkata
# 64  Senior Software Engineer  127000                19    Gurugram
# 65  Senior Software Engineer  122000                19   Hyderabad
# ...

# %%
emp_from = df[df['City'] .isin (['Delhi','Chandigarh'])]
print(emp_from)
# Out:
#     Employee_ID           Name  Age  Gender        Department  \
# 0             1  Aditya Sharma   38    Male         Marketing
# 3             4    Varun Patel   25    Male         Marketing
# 6             7    Vikas Joshi   44    Male           Finance
# 16           17  Sameer Khanna   31    Male                HR
# 19           20    Zoya Khanna   21  Female                HR
# 20           21    Isha Khanna   52  Female                IT
# 29           30   Gaurav Patel   30    Male                IT
# 32           33    Rahul Gupta   39    Male             Sales
# 38           39  Deepak Kapoor   27    Male             Sales
# 42           43    Akash Mehta   47  Female         Marketing
# 50           51    Rahul Singh   50  Female      Data Science
# 53           54     Riya Gupta   41  Female        Operations
# 54           55    Rahul Verma   34  Female           Finance
# 60           61    Kavya Ahuja   55    Male                HR
# ...

# %%
print(df[df['Salary'].between(40000, 80000)])
# Out:
#     Employee_ID           Name  Age  Gender        Department  \
# 2             3    Akash Joshi   27  Female        Operations
# 3             4    Varun Patel   25    Male         Marketing
# 8             9    Diya Khanna   27  Female         Marketing
# 9            10    Karan Mehta   24    Male                HR
# 11           12    Vikas Mehta   21    Male                IT
# 19           20    Zoya Khanna   21  Female                HR
# 21           22   Pooja Mishra   21    Male                HR
# 37           38    Harsh Patel   22    Male         Marketing
# 38           39  Deepak Kapoor   27    Male             Sales
# 71           72    Akash Patel   22    Male        Operations
# 74           75    Karan Arora   22    Male  Customer Support
# 80           81    Arjun Kumar   22    Male         Marketing
# 83           84   Jatin Bansal   28    Male  Customer Support
# 84           85  Abhinav Sethi   22  Female                HR
# ...

# %%
print(df[(df['Performance_Score'] > 8) & (df['Experience_Years'] > 3)])
# Out:
#     Employee_ID            Name  Age  Gender        Department  \
# 8             9     Diya Khanna   27  Female         Marketing
# 12           13     Harsh Ahuja   47    Male                HR
# 13           14   Kritika Singh   36    Male         Marketing
# 15           16      Isha Arora   39  Female  Customer Support
# 23           24  Harsh Malhotra   31    Male      Data Science
# 24           25      Esha Joshi   42  Female                HR
# 28           29      Riya Arora   49    Male  Customer Support
# 33           34   Pankaj Bansal   55  Female      Data Science
# 35           36      Riya Kumar   55    Male      Data Science
# 39           40     Varun Verma   43  Female        Operations
# 45           46   Ananya Mishra   39    Male  Customer Support
# 47           48    Shreya Joshi   49  Female             Sales
# 52           53    Rohan Chopra   47  Female        Operations
# 53           54      Riya Gupta   41  Female        Operations
# ...

# %%
print(df[df['Name'].str.startswith('A')])
# Out:
#     Employee_ID            Name  Age  Gender        Department  \
# 0             1   Aditya Sharma   38    Male         Marketing
# 2             3     Akash Joshi   27  Female        Operations
# 5             6     Arjun Patel   57  Female         Marketing
# 14           15     Anika Verma   55    Male                HR
# 26           27    Aarav Khanna   55    Male        Operations
# 42           43     Akash Mehta   47  Female         Marketing
# 45           46   Ananya Mishra   39    Male  Customer Support
# 46           47    Aditya Gupta   46  Female                HR
# 49           50     Arjun Mehta   37    Male      Data Science
# 55           56     Akash Mehta   28  Female                HR
# 59           60     Aarav Kumar   47    Male                HR
# 64           65     Aditi Joshi   38    Male                IT
# 65           66     Anika Verma   40  Female                IT
# 70           71  Abhinav Chopra   34  Female  Customer Support
# ...

# %%
descending_order = df.sort_values(by='Salary', ascending=False)
print(descending_order)
# Out:
#     Employee_ID           Name  Age  Gender        Department  \
# 75           76  Ishaan Saxena   58  Female      Data Science
# 43           44   Rohan Mishra   54  Female      Data Science
# 33           34  Pankaj Bansal   55  Female      Data Science
# 35           36     Riya Kumar   55    Male      Data Science
# 50           51    Rahul Singh   50  Female      Data Science
# ..          ...            ...  ...     ...               ...
# 83           84   Jatin Bansal   28    Male  Customer Support
# 11           12    Vikas Mehta   21    Male                IT
# 74           75    Karan Arora   22    Male  Customer Support
# 21           22   Pooja Mishra   21    Male                HR
# 19           20    Zoya Khanna   21  Female                HR
#
#                  Job_Role  Salary  Experience_Years        City Joining_Date  \
# 75  Senior Data Scientist  170000                25    Gurugram   2020-11-01
# ...

# %%
print(df.sort_values(by=['Department', 'Salary'], ascending=[True, False]))
# Out:
#     Employee_ID           Name  Age  Gender        Department  \
# 31           32    Yash Bansal   49  Female  Customer Support
# 63           64   Vikas Kapoor   48  Female  Customer Support
# 28           29     Riya Arora   49    Male  Customer Support
# 15           16     Isha Arora   39  Female  Customer Support
# 45           46  Ananya Mishra   39    Male  Customer Support
# ..          ...            ...  ...     ...               ...
# 66           67  Shreya Khanna   38    Male             Sales
# 10           11     Yash Sethi   34    Male             Sales
# 99          100    Pooja Singh   39    Male             Sales
# 44           45     Diya Patel   34  Female             Sales
# 38           39  Deepak Kapoor   27    Male             Sales
#
#               Job_Role  Salary  Experience_Years        City Joining_Date  \
# 31  Support Specialist  129000                25   Hyderabad   2024-06-10
# ...

# %%
print(df.sort_values(by='Salary', ascending=False).head(5))
# Out:
#     Employee_ID           Name  Age  Gender    Department  \
# 75           76  Ishaan Saxena   58  Female  Data Science
# 43           44   Rohan Mishra   54  Female  Data Science
# 33           34  Pankaj Bansal   55  Female  Data Science
# 35           36     Riya Kumar   55    Male  Data Science
# 50           51    Rahul Singh   50  Female  Data Science
#
#                  Job_Role  Salary  Experience_Years        City Joining_Date  \
# 75  Senior Data Scientist  170000                25    Gurugram   2020-11-01
# 43  Senior Data Scientist  168000                25   Hyderabad   2019-06-13
# 33         Data Scientist  167000                25      Jaipur   2026-02-27
# 35         Data Scientist  167000                25      Mumbai   2025-09-24
# 50  Senior Data Scientist  167000                25  Chandigarh   2022-09-19
#
#     Performance_Score    Bonus Education
# 75                6.0   8500.0       BBA
# 43                8.0  13440.0       PhD
# ...

# %%
print(df.isnull().sum())
# Out:
# Employee_ID          0
# Name                 0
# Age                  0
# Gender               0
# Department           0
# Job_Role             0
# Salary               0
# Experience_Years     0
# City                 2
# Joining_Date         0
# Performance_Score    4
# Bonus                7
# Education            0
# dtype: int64

# %%
df['Bonus'] = df['Bonus'].fillna(0)
print(df)
# Out:
#     Employee_ID           Name  Age  Gender        Department  \
# 0             1  Aditya Sharma   38    Male         Marketing
# 1             2    Tanya Patel   55  Female         Marketing
# 2             3    Akash Joshi   27  Female        Operations
# 3             4    Varun Patel   25    Male         Marketing
# 4             5   Ishaan Gupta   31    Male           Finance
# ..          ...            ...  ...     ...               ...
# 95           96    Karan Ahuja   33  Female  Customer Support
# 96           97   Ananya Ahuja   44    Male                HR
# 97           98  Manish Sharma   47    Male      Data Science
# 98           99   Chetan Kumar   23  Female  Customer Support
# 99          100    Pooja Singh   39    Male             Sales
#
#                  Job_Role  Salary  Experience_Years        City Joining_Date  \
# 0     Marketing Executive  114000                16  Chandigarh   2022-08-19
# ...

# %%
df['Total_Salary'] = df['Salary'] + df['Bonus']
print(df)
# Out:
#     Employee_ID           Name  Age  Gender        Department  \
# 0             1  Aditya Sharma   38    Male         Marketing
# 1             2    Tanya Patel   55  Female         Marketing
# 2             3    Akash Joshi   27  Female        Operations
# 3             4    Varun Patel   25    Male         Marketing
# 4             5   Ishaan Gupta   31    Male           Finance
# ..          ...            ...  ...     ...               ...
# 95           96    Karan Ahuja   33  Female  Customer Support
# 96           97   Ananya Ahuja   44    Male                HR
# 97           98  Manish Sharma   47    Male      Data Science
# 98           99   Chetan Kumar   23  Female  Customer Support
# 99          100    Pooja Singh   39    Male             Sales
#
#                  Job_Role  Salary  Experience_Years        City Joining_Date  \
# 0     Marketing Executive  114000                16  Chandigarh   2022-08-19
# ...

# %%
print(df.groupby('Department')['Salary'].mean())
# Out:
# Department
# Customer Support     90866.666667
# Data Science        143909.090909
# Finance             123714.285714
# HR                  100600.000000
# IT                  111125.000000
# Marketing           108461.538462
# Operations          117285.714286
# Sales               118500.000000
# Name: Salary, dtype: float64

# %%
print(df.groupby('Department').agg(
    Total_Employees=('Employee_ID', 'count'),
    Average_Salary=('Salary', 'mean'),
    Maximum_Salary=('Salary', 'max'),
    Minimum_Salary=('Salary', 'min'),
    Average_Performance_Score=('Performance_Score', 'mean')
))
# Out:
#                   Total_Employees  Average_Salary  Maximum_Salary  \
# Department
# Customer Support               15    90866.666667          129000
# Data Science                   11   143909.090909          170000
# Finance                         7   123714.285714          148000
# HR                             20   100600.000000          133000
# IT                              8   111125.000000          149000
# Marketing                      13   108461.538462          145000
# Operations                     14   117285.714286          143000
# Sales                          12   118500.000000          145000
#
#                   Minimum_Salary  Average_Performance_Score
# Department
# Customer Support           48000                   8.200000
# Data Science               97000                   7.700000
# Finance                   106000                   7.200000
# HR                         43000                   7.736842
# ...
